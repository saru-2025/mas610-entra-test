# %%
# --- CONFIGURE THESE 4 VALUES ---
storage_account = "stdatahubsg"     # e.g. bankdataplatformsg
tenant_id       = "6aaeadfe-7abb-4f83-96c7-d0aa5d9a549a"           # e.g. 72f988bf-xxxx-xxxx-xxxx
scope_name      = "adls-secrets"               # the scope you just made
client_id = "8e6acee3-14bf-4100-965a-dcaa80fb98b0"
client_secret = "49B8Q~VvOevExdhd4BeF-Z_KqmcrcJQAFlXw9bIt"

# OAuth configuration
configs = {
  "fs.azure.account.auth.type": "OAuth",
  "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
  "fs.azure.account.oauth2.client.id": client_id,
  "fs.azure.account.oauth2.client.secret": client_secret,
  "fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{tenant_id}/oauth2/token"
}

# 🔧 3. Mount all three layers (raw, silver, gold)
for layer in ["raw", "silver", "gold"]:
    mount_point = f"/mnt/{layer}"
    source = f"abfss://{layer}@{storage_account}.dfs.core.windows.net/"

    try:
        dbutils.fs.mount(
            source      = source,
            mount_point = mount_point,
            extra_configs = configs
        )
        print(f"✅ Mounted {layer} container successfully at {mount_point}")
    except Exception as e:
        print(f"⚠️ Skipped mounting {layer} (maybe already mounted) — {e}")

# 🔧 4. Verify
display(dbutils.fs.mounts())

# %%
# Unmount
dbutils.fs.unmount("/mnt/raw")
dbutils.fs.unmount("/mnt/silver")
dbutils.fs.unmount("/mnt/gold")

# %%
display(dbutils.fs.ls("/mnt/raw"))
display(dbutils.fs.ls("/mnt/gold"))

# %%
display(dbutils.fs.mounts())
